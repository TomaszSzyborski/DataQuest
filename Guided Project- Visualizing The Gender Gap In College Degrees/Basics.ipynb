# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
# Stem categories
stem_cats = ['Psychology',
             'Biology',
             'Math and Statistics',
             'Physical Sciences',
             'Computer Science',
             'Engineering', 
             'Computer Science']
# Art categories
lib_arts_cats = ['Foreign Languages',
                 'English',
                 'Communications and Journalism',
                 'Art and Performance',
                 'Social Sciences and History']

# Other categories
other_cats = ['Health Professions',
              'Public Administration',
              'Education',
              'Agriculture',
              'Business',
              'Architecture']

# %%
# %matplotlib inline

def makeplots(categories):
    cb_dark_blue = (0/255,107/255,164/255)
    cb_orange = (255/255, 128/255, 14/255)

    fig = plt.figure(figsize=(18, 3))

    for category in range(len(categories)):
        ax = fig.add_subplot(1,6,sp+1)
        ax.plot(women_degrees['Year'],
                women_degrees[categories[category]],
                c=cb_dark_blue,
                label='Women',
                linewidth=3)
        
        ax.plot(women_degrees['Year'],
                100-women_degrees[categories[category]],
                c=cb_orange,
                label='Men',
                linewidth=3)
        
        ax.spines["right"].set_visible(False)    
        ax.spines["left"].set_visible(False)
        ax.spines["top"].set_visible(False)    
        ax.spines["bottom"].set_visible(False)
        
        ax.set_xlim(1968, 2011)
        ax.set_ylim(0,100)
        ax.set_title(categories[category])
        
        ax.tick_params(bottom="off",
                       top="off",
                       left="off",
                       right="off")

        if sp == 0:
            ax.text(2005, 87, 'Men')
            ax.text(2002, 8, 'Women')
        elif sp == 5:
            ax.text(2005, 62, 'Men')
            ax.text(2001, 35, 'Women')

            
makeplots(stem_cats)
makeplots(lib_arts_cats)
makeplots(other_cats)

plt.show()

# %%
# data for generate_plot function |start_range|end_range|category_data|
stem_column = [0, 18, stem_cats]
lib_arts_column = [1, 16, lib_arts_cats]
other_column = [2, 20, other_cats]

#set plot canvas
fig = plt.figure(figsize=(16, 16))

def generate_plot(column_number, end_range, category):
    for sp in range(column_number,end_range,3):
        cat_index = int((sp-column_number)/3)
        
        ax = fig.add_subplot(6,3,sp+1)
        ax.plot(women_degrees['Year'], women_degrees[category[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[category[cat_index]], c=cb_orange, label='Men', linewidth=3)
       
        for key,spine in ax.spines.items():
            spine.set_visible(False)
        
        ax.set_xlim(1968, 2011)
        ax.set_ylim(0,100)
        ax.set_title(category[cat_index])
        ax.tick_params(bottom="off",
                       top="off", left="off", right="off")
        
        if cat_index == 0:
            ax.text(2003, 85, 'Women')
            ax.text(2005, 10, 'Men')
        elif cat_index == 5 and column_number != 1:
            ax.text(2005, 87, 'Men')
            ax.text(2003, 7, 'Women')

generate_plot(*stem_column)
generate_plot(*lib_arts_column)
generate_plot(*other_column)

plt.show()

# %% [markdown]
# # 3: Hiding X-Axis Labels

# %%
# data for generate_plot function |start_range|end_range|category_data|
stem_column = [0, 18, stem_cats]
lib_arts_column = [1, 16, lib_arts_cats]
other_column = [2, 20, other_cats]

#set plot canvas
fig = plt.figure(figsize=(16, 16))

def generate_plot(column_number, end_range, category):
    for sp in range(column_number,end_range,3):
        cat_index = int((sp-column_number)/3)
        
        ax = fig.add_subplot(6,3,sp+1)
        ax.plot(women_degrees['Year'], women_degrees[category[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[category[cat_index]], c=cb_orange, label='Men', linewidth=3)
       
        for key,spine in ax.spines.items():
            spine.set_visible(False)
        
        ax.set_xlim(1968, 2011)
        ax.set_ylim(0,100)
        ax.set_title(category[cat_index])
        
        ax.tick_params(bottom="off",
                       top="off",
                       left="off",
                       right="off",
                      labelbottom='off')
        
        if cat_index ==5 or (cat_index==4 and column_number ==1):
            ax.tick_params(labelbottom='on')
        
        if cat_index == 0:
            ax.text(2003, 85, 'Women')
            ax.text(2005, 10, 'Men')
        elif cat_index == 5 and column_number != 1:
            ax.text(2005, 87, 'Men')
            ax.text(2003, 7, 'Women')
        

generate_plot(*stem_column)
generate_plot(*lib_arts_column)
generate_plot(*other_column)

plt.show()

# %% [markdown]
# # 4: Setting Y-Axis Labels

# %%
# data for generate_plot function |start_range|end_range|category_data|
stem_column = [0, 18, stem_cats]
lib_arts_column = [1, 16, lib_arts_cats]
other_column = [2, 20, other_cats]

#set plot canvas
fig = plt.figure(figsize=(16, 16))

def generate_plot(column_number, end_range, category):
    for sp in range(column_number,end_range,3):
        cat_index = int((sp-column_number)/3)
        
        ax = fig.add_subplot(6,3,sp+1)
        ax.plot(women_degrees['Year'], women_degrees[category[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[category[cat_index]], c=cb_orange, label='Men', linewidth=3)
       
        for key,spine in ax.spines.items():
            spine.set_visible(False)
        
        # setting limits for axes
        ax.set_xlim(1968, 2011)
        ax.set_ylim(0,100)
        
        # setting title for graph
        ax.set_title(category[cat_index])
        
        # turning off tick parameters
        ax.tick_params(bottom="off",
                       top="off",
                       left="off",
                       right="off",
                      labelbottom='off')
        
        # setting lowest graph bottom label
        if cat_index==5 or (cat_index==4 and column_number ==1):
            ax.tick_params(labelbottom='on')
        
        # setting y-axis ticks    
        ax.set_yticks([0,100])
        
        if cat_index == 0:
            ax.text(2003, 85, 'Women')
            ax.text(2005, 10, 'Men')
        elif cat_index == 5 and column_number != 1:
            ax.text(2005, 87, 'Men')
            ax.text(2003, 7, 'Women')
        

generate_plot(*stem_column)
generate_plot(*lib_arts_column)
generate_plot(*other_column)

plt.show()

# %% [markdown]
# # 5: Adding A Horizontal Line

# %%
# data for generate_plot function |start_range|end_range|category_data|
stem_column = [0, 18, stem_cats]
lib_arts_column = [1, 16, lib_arts_cats]
other_column = [2, 20, other_cats]

#set plot canvas
fig = plt.figure(figsize=(16, 16))

def generate_plot(column_number, end_range, category):
    for sp in range(column_number,end_range,3):
        cat_index = int((sp-column_number)/3)
        
        ax = fig.add_subplot(6,3,sp+1)
        ax.plot(women_degrees['Year'], women_degrees[category[cat_index]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[category[cat_index]], c=cb_orange, label='Men', linewidth=3)
       
        for key,spine in ax.spines.items():
            spine.set_visible(False)
        
        # setting limits for axes
        ax.set_xlim(1968, 2011)
        ax.set_ylim(0,100)
        
        # setting title for graph
        ax.set_title(category[cat_index])
        
        # turning off tick parameters
        ax.tick_params(bottom="off",
                       top="off",
                       left="off",
                       right="off",
                      labelbottom='off')
        
        # setting lowest graph bottom label
        if cat_index==5 or (cat_index==4 and column_number ==1):
            ax.tick_params(labelbottom='on')
        
        # setting y-axis ticks    
        ax.set_yticks([0,100])
        
        # adding horizontal line to graph
        ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
        
        if cat_index == 0:
            ax.text(2003, 85, 'Women')
            ax.text(2005, 10, 'Men')
        elif cat_index == 5 and column_number != 1:
            ax.text(2005, 87, 'Men')
            ax.text(2003, 7, 'Women')
        

generate_plot(*stem_column)
generate_plot(*lib_arts_column)
generate_plot(*other_column)

plt.show()

# %%
# 6: Exporting to a file

# %%
plt.savefig("gender_degrees.png")
